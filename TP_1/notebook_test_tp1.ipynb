# %% [markdown]
# # Trabajo Práctico 1
# Notebook de prueba para TP 1.

# %%
# Out:
# Versión del Intérprete Python: 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:29:05) [MSC v.1942 64 bit (AMD64)]
# Versión de NumPy: 2.5.1
# Versión de Pandas: 3.0.5
# Versión de Scikit-learn: 1.9.0
# ¡El Workspace en Antigravity IDE y el entorno virtual se ejecutan correctamente!
